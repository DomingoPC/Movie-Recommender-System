# %% [markdown]
# # Introduction
#
# Data extracted from [Kaggle (The Movies Dataset)](https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset?select=ratings.csv).

# %%
# Load libraries
import pandas as pd
import re
from pyspark.sql.functions import regexp_extract, col, regexp_extract_all, lit, size
from helper_functions import *

# Initialize Spark Session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("ETL").getOrCreate()
print(spark)
# Out:
# <pyspark.sql.session.SparkSession object at 0x000001C68EC602B0>

# %% [markdown]
# Files from the movies dataset:

# %%
import os
os.listdir("data")
# Out:
# ['archive.zip',
#  'cleaned',
#  'credits.csv',
#  'keywords.csv',
#  'links.csv',
#  'links_small.csv',
#  'movies_metadata.csv',
#  'movies_metadata_regex.csv',
#  'ratings.csv',
#  'ratings_small.csv']

# %% [markdown]
# ## Ratings
# This is the main dataset for the collaborative-filtering recommender system, as it contains opinions from the users about the movies.

# %%
df = load_and_show('data/ratings.csv', 
                   spark_session=spark, parquet=False)
# Out:
# Columns data types:
#   Column Name Data Type
# 0      userId       int
# 1     movieId       int
# 2      rating    double
# 3   timestamp       int
# Number of partitions = 20
# Number of entries/rows = 26024289
#
# Data sample:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556
# Data description:
#   summary             userId             movieId              rating  \
# 0   count           26024289            26024289            26024289
# 1    mean   135037.090248114  15849.109677040553  3.5280903543608817
# 2  stddev  78176.19722170144  31085.257531391675  1.0654427636662278
# 3     min                  1                   1                 0.5
# 4     max             270896              176275                 5.0
#
#               timestamp
# 0              26024289
# 1  1.1712584326913226E9
# 2  2.0528887028184557E8
# 3             789652004
# 4            1501829870

# %% [markdown]
# The column `timestamp` is not needed, because for a collaborative-filtering only the userId, itemId and rating are valuable. Let's write the full list of ratings without that column:

# %%
# Save cleaned ratings .csv file
df.drop('timestamp').\
    write.parquet('data/cleaned/ratings', mode='overwrite')

# %% [markdown]
# ## Movies Metadata
# This one contains lots of information about every movie in the dataset. However, when loading it for the first time, it was clear that there were reading problems. By checking the information in every column, it became apparent that extensive text entries caused them. The reasons are:
#
# 1. In some columns, like `overview`, there are commas, which are problematic when reading a file with comma-sepparated values. Nevertheless, when this happens the entry is contained between double quotation marks ("), so it is possible to avoid this wrong behaviour by specifying they indicate quotations.
#
# 2. These same texts include line breaks (\n) and, although it occures sparsely, it makes a single line be read as two or more.
#
# Let's start solving the second problem:

# %%
import re

# Open a new document to write the corrected lines
with open('data/movies_metadata_regex.csv', 'w+') as w:

    # Read the lines of movies_metadata.csv to locate and
    # correct the ones with line breaks
    with open('data/movies_metadata.csv', 'r') as r:
        # Skip first line of the iterable
        current_line = r.readline() # Header

        # Check every line
        for line in r:
            # Get first value of the line
            first_value = re.findall(r'^[^\,]*', line)[0]

            # Based on the first value, it is possible to know where there is a mistake or not
            # Correct values: True or False, in the 'Adult' column
            # Incorrect values: text from an overview or any other long text
            if first_value in ('False', 'True'):
                # Write resulting line:
                # + First one will be the header
                # + All \n are removed
                # + After that, include a \n at the end
                w.write(re.sub('\n', '', current_line) + '\n')

                # New line
                current_line = line
            else:
                # Append the line to the previous one
                current_line = current_line + line
        
        # Write last line
        w.write(re.sub('\n', '', current_line) + '\n')

# %% [markdown]
# Now, it is possible to read the .csv file by specifying the symbol " is the quotation character (already included in the helper function `load_and_show`):

# %%
df = load_and_show('data/movies_metadata_regex.csv',
                   spark_session=spark, parquet=False)
# Out:
# Columns data types:
#               Column Name Data Type
# 0                   adult   boolean
# 1   belongs_to_collection    string
# 2                  budget       int
# 3                  genres    string
# 4                homepage    string
# 5                      id       int
# 6                 imdb_id    string
# 7       original_language    string
# 8          original_title    string
# 9                overview    string
# 10             popularity    double
# 11            poster_path    string
# 12   production_companies    string
# 13   production_countries    string
# 14           release_date      date
# 15                revenue    bigint
# 16                runtime    double
# 17       spoken_languages    string
# 18                 status    string
# 19                tagline    string
# 20                  title    string
# 21                  video   boolean
# 22           vote_average    double
# 23             vote_count       int
# Number of partitions = 9
# Number of entries/rows = 45463
#
# Data sample:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                               None  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                               None  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                  None   8844  tt0113497                en
# 2                                  None  15602  tt0113228                en
# 3                                  None  31357  tt0114885                en
# 4                                  None  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#      revenue runtime                                   spoken_languages  \
# 0  373554033    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                               None
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7       5415
# 1                      Jumanji  False          6.9       2413
# 2             Grumpier Old Men  False          6.5         92
# 3            Waiting to Exhale  False          6.1         34
# 4  Father of the Bride Part II  False          5.7        173
#
# [5 rows x 24 columns]
# Data description:
#   summary                              belongs_to_collection  \
# 0   count                                               4491
# 1    mean                                               None
# 2  stddev                                               None
# 3     min  {'id': 10, 'name': 'Star Wars Collection', 'po...
# 4     max  {'id': 99727, 'name': 'Stuart Little Collectio...
#
#                  budget                               genres  \
# 0                 45463                                45463
# 1     4224578.813474693                                 None
# 2  1.7424132634341218E7                                 None
# 3                     0                                   []
# 4             380000000  [{'id': 99, 'name': 'Documentary'}]
#
#                                     homepage                  id    imdb_id  \
# 0                                       7779               45463      45446
# 1                                       None  108359.91881310077       None
# 2                                       None  112460.74927813222       None
# 3                         http://009.ph9.jp/                   2  tt0000001
# 4  https://zeitgeistfilms.com/film/writerofo              469172  tt7158814
#
#   original_language         original_title  \
# 0             45452                  45463
# 1              None               Infinity
# 2              None                    NaN
# 3                ab  !Women Art Revolution
# 4                zu     ＳＭガールズ セイバーマリオネットＲ
#
#                                             overview  ...  \
# 0                                              44509  ...
# 1                                               None  ...
# 2                                               None  ...
# 3                                                     ...
# 4  …ere erera baleibu izik subua aruaren…, a set ...  ...
#
#                production_companies  \
# 0                             45463
# 1                              None
# 2                              None
# 3                                []
# 4  [{'name': '프로덕션M', 'id': 19104}]
#
#                              production_countries              revenue  \
# 0                                           45463                45463
# 1                                            None  1.120860885984207E7
# 2                                            None  6.433018853029212E7
# 3                                              []                    0
# 4  [{'iso_3166_1': 'ZA', 'name': 'South Africa'}]           2787965087
#
#               runtime                          spoken_languages    status  \
# 0               45206                                     45463     45382
# 1   94.12757156129717                                      None      None
# 2  38.406803036934555                                      None      None
# 3                 0.0                                        []  Canceled
# 4              1256.0  [{'iso_639_1': 'zu', 'name': 'isiZulu'}]   Rumored
#
#     tagline                  title        vote_average          vote_count
# 0     20413                  45463               45463               45463
# 1    1942.0               Infinity   5.618217011635818  109.89085630072806
# 2      None                    NaN  1.9241741806737938  491.29481601544893
# 3            !Women Art Revolution                 0.0                   0
# 4  李麗珍蜜桃成熟時               ファンタスティポ                10.0               14075
#
# [5 rows x 22 columns]

# %% [markdown]
# Not only did it get the right structure, but it also infered the correct schema, which indicates the correction was successful.
#
# Another issue with this data is the presence of JSON files in some of the columns (specifically, lists of JSON files). This is the case for:
# + `belongs to collection`.
# + `genres`.
# + `production_companies`.
# + `production_countries`.
# + `spoken_languages`.
#
# Instead of that, it can be transformed into a list of items (genres, languages, etc.).
#
# On the other hand, there are several columns that don't have much of an impact on the analysis:
# + `homepage`.
# + `imdb_id`.
# + `poster_path`.
# + `original_title`.
#
# This can easily be solved with the next code:

# %%
# Drop useless columns
df = df.drop('homepage', 'imdb_id', 'poster_path', 'original_title')
df.show(5)
# Out:
# +-----+---------------------+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+
# |adult|belongs_to_collection|  budget|              genres|   id|original_language|            overview|popularity|production_companies|production_countries|release_date|  revenue|runtime|    spoken_languages|  status|             tagline|               title|video|vote_average|vote_count|
# +-----+---------------------+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+
# |false| {'id': 10194, 'na...|30000000|[{'id': 16, 'name...|  862|               en|Led by Woody, And...| 21.946943|[{'name': 'Pixar ...|[{'iso_3166_1': '...|  1995-10-30|373554033|   81.0|[{'iso_639_1': 'e...|Released|                NULL|           Toy Story|false|         7.7|      5415|
# |false|                 NULL|65000000|[{'id': 12, 'name...| 8844|               en|When siblings Jud...| 17.015539|[{'name': 'TriSta...|[{'iso_3166_1': '...|  1995-12-15|262797249|  104.0|[{'iso_639_1': 'e...|Released|Roll the dice and...|             Jumanji|false|         6.9|      2413|
# |false| {'id': 119050, 'n...|       0|[{'id': 10749, 'n...|15602|               en|A family wedding ...|   11.7129|[{'name': 'Warner...|[{'iso_3166_1': '...|  1995-12-22|        0|  101.0|[{'iso_639_1': 'e...|Released|Still Yelling. St...|    Grumpier Old Men|false|         6.5|        92|
# |false|                 NULL|16000000|[{'id': 35, 'name...|31357|               en|Cheated on, mistr...|  3.859495|[{'name': 'Twenti...|[{'iso_3166_1': '...|  1995-12-22| 81452156|  127.0|[{'iso_639_1': 'e...|Released|Friends are the p...|   Waiting to Exhale|false|         6.1|        34|
# |false| {'id': 96871, 'na...|       0|[{'id': 35, 'name...|11862|               en|Just when George ...|  8.387519|[{'name': 'Sandol...|[{'iso_3166_1': '...|  1995-02-10| 76578911|  106.0|[{'iso_639_1': 'e...|Released|Just When His Wor...|Father of the Bri...|false|         5.7|       173|
# +-----+---------------------+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+
# only showing top 5 rows

# %% [markdown]
# Now, let's focus on the challenging part, finding a way to transform a string that represents a list of JSON files into a list of items. One way to do this is with regular expressions, which can be applied row wise with PySpark.
#
# Let's take a sample to check if this approach is valid:

# %%
sample = df.limit(3).\
    select('belongs_to_collection', 'genres', 
           'production_companies', 'production_countries',
           'spoken_languages').\
    toPandas()
    
display(sample)
# Out:
#                                belongs_to_collection  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1                                               None
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
#
#                                 production_countries  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                                     spoken_languages
# 0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2           [{'iso_639_1': 'en', 'name': 'English'}]

# %% [markdown]
# + `belongs_to_collection`: the only important piece of information is the name of the collection (stored under 'name' field).
#
# + `genres`: it is a list of JSON files. Each of them contains the field 'name', which indicates one of the genres associated with the movie.
#
# + `production_companies`: it is a list of JSON files. The names of the companies are stored under the field 'name', similar to `genres`.
#
# + `production_countries`: it is a list of JSON files. Again, the country name is stored under the field 'name', but the abbreviation for it is also accesible (in this case, under the field 'iso_3166_1').
#
# + `spoken_languages`: it is a list of JSON files. It is the same as `production_countries`, except the abbreviation is stored under 'iso_639_1'.

# %%
# Example: extract information under the field 'name'
l_json = sample.loc[0,'spoken_languages']
re.findall(
    pattern=r'(?<=\'name\': \')([^\']*)(?=\')',
    string=l_json
)
# Out:
# ['English']

# %%
# Example: extract information under the field 'iso_3166_1'
l_json = sample.loc[0,'production_countries']
re.findall(
    pattern=r'(?<=\'iso_3166_1\': \')([^\']*)(?=\')',
    string=l_json
)
# Out:
# ['US']

# %%
# Example: extract information under the field 'iso_639_1'
l_json = sample.loc[0,'spoken_languages']
re.findall(
    pattern=r'(?<=\'iso_639_1\': \')([^\']*)(?=\')',
    string=l_json
)
# Out:
# ['en']

# %% [markdown]
# All that is left to do is extract this information for the full column using PySpark:

# %%
# Collection: a single collection for each movie (not a list of JSONs)
df = df.withColumn(
    'collection', 
    regexp_extract(col('belongs_to_collection'), 
        r'(?<=\'name\': \')([^\']*)(?=\')', 
        1)
    ).\
    drop('belongs_to_collection')
df.show(5)
# Out:
# +-----+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+--------------------+
# |adult|  budget|              genres|   id|original_language|            overview|popularity|production_companies|production_countries|release_date|  revenue|runtime|    spoken_languages|  status|             tagline|               title|video|vote_average|vote_count|          collection|
# +-----+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+--------------------+
# |false|30000000|[{'id': 16, 'name...|  862|               en|Led by Woody, And...| 21.946943|[{'name': 'Pixar ...|[{'iso_3166_1': '...|  1995-10-30|373554033|   81.0|[{'iso_639_1': 'e...|Released|                NULL|           Toy Story|false|         7.7|      5415|Toy Story Collection|
# |false|65000000|[{'id': 12, 'name...| 8844|               en|When siblings Jud...| 17.015539|[{'name': 'TriSta...|[{'iso_3166_1': '...|  1995-12-15|262797249|  104.0|[{'iso_639_1': 'e...|Released|Roll the dice and...|             Jumanji|false|         6.9|      2413|                NULL|
# |false|       0|[{'id': 10749, 'n...|15602|               en|A family wedding ...|   11.7129|[{'name': 'Warner...|[{'iso_3166_1': '...|  1995-12-22|        0|  101.0|[{'iso_639_1': 'e...|Released|Still Yelling. St...|    Grumpier Old Men|false|         6.5|        92|Grumpy Old Men Co...|
# |false|16000000|[{'id': 35, 'name...|31357|               en|Cheated on, mistr...|  3.859495|[{'name': 'Twenti...|[{'iso_3166_1': '...|  1995-12-22| 81452156|  127.0|[{'iso_639_1': 'e...|Released|Friends are the p...|   Waiting to Exhale|false|         6.1|        34|                NULL|
# |false|       0|[{'id': 35, 'name...|11862|               en|Just when George ...|  8.387519|[{'name': 'Sandol...|[{'iso_3166_1': '...|  1995-02-10| 76578911|  106.0|[{'iso_639_1': 'e...|Released|Just When His Wor...|Father of the Bri...|false|         5.7|       173|Father of the Bri...|
# +-----+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+--------------------+
# only showing top 5 rows

# %%
# Columns with lists of JSONs (list of items)
df = df.\
    withColumn(
        'genres', 
        regexp_extract_all('genres', 
            lit(r'(?<=\'name\': \')([^\']*)(?=\')').alias('d'))   
    ).\
    withColumn(
        'production_companies', 
        regexp_extract_all('production_companies', 
            lit(r'(?<=\'name\': \')([^\']*)(?=\')').alias('d'))   
    ).\
    withColumn(
        'production_countries', 
        regexp_extract_all('production_countries', 
            lit(r'(?<=\'name\': \')([^\']*)(?=\')').alias('d'))   
    ).\
    withColumn(
        'spoken_languages', 
        regexp_extract_all('spoken_languages', 
            lit(r'(?<=\'name\': \')([^\']*)(?=\')').alias('d'))   
    )

display(df.limit(5).toPandas())
# Out:
#    adult    budget                        genres     id original_language  \
# 0  False  30000000   [Animation, Comedy, Family]    862                en
# 1  False  65000000  [Adventure, Fantasy, Family]   8844                en
# 2  False         0             [Romance, Comedy]  15602                en
# 3  False  16000000      [Comedy, Drama, Romance]  31357                en
# 4  False         0                      [Comedy]  11862                en
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#                                 production_companies  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2                     [Warner Bros., Lancaster Gate]
# 3           [Twentieth Century Fox Film Corporation]
# 4       [Sandollar Productions, Touchstone Pictures]
#
#          production_countries release_date    revenue  runtime  \
# 0  [United States of America]   1995-10-30  373554033     81.0
# 1  [United States of America]   1995-12-15  262797249    104.0
# 2  [United States of America]   1995-12-22          0    101.0
# 3  [United States of America]   1995-12-22   81452156    127.0
# 4  [United States of America]   1995-02-10   76578911    106.0
#
#       spoken_languages    status  \
# 0            [English]  Released
# 1  [English, Français]  Released
# 2            [English]  Released
# 3            [English]  Released
# 4            [English]  Released
#
#                                              tagline  \
# 0                                               None
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count  \
# 0                    Toy Story  False           7.7        5415
# 1                      Jumanji  False           6.9        2413
# 2             Grumpier Old Men  False           6.5          92
# 3            Waiting to Exhale  False           6.1          34
# 4  Father of the Bride Part II  False           5.7         173
#
#                        collection
# 0            Toy Story Collection
# 1                            None
# 2       Grumpy Old Men Collection
# 3                            None
# 4  Father of the Bride Collection

# %%
for column in ['genres', 'production_companies', 'production_countries', 'spoken_languages']:
    print('n_' + column)
    df = df.withColumn('n_' + column, size(df[column]))

df.show()
# Out:
# n_genres
# n_production_companies
# n_production_countries
# n_spoken_languages
# +-----+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+--------------------+--------+----------------------+----------------------+------------------+
# |adult|  budget|              genres|   id|original_language|            overview|popularity|production_companies|production_countries|release_date|  revenue|runtime|    spoken_languages|  status|             tagline|               title|video|vote_average|vote_count|          collection|n_genres|n_production_companies|n_production_countries|n_spoken_languages|
# +-----+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+--------------------+--------+----------------------+----------------------+------------------+
# |false|30000000|[Animation, Comed...|  862|               en|Led by Woody, And...| 21.946943|[Pixar Animation ...|[United States of...|  1995-10-30|373554033|   81.0|           [English]|Released|                NULL|           Toy Story|false|         7.7|      5415|Toy Story Collection|       3|                     1|                     1|                 1|
# |false|65000000|[Adventure, Fanta...| 8844|               en|When siblings Jud...| 17.015539|[TriStar Pictures...|[United States of...|  1995-12-15|262797249|  104.0| [English, Français]|Released|Roll the dice and...|             Jumanji|false|         6.9|      2413|                NULL|       3|                     3|                     1|                 2|
# |false|       0|   [Romance, Comedy]|15602|               en|A family wedding ...|   11.7129|[Warner Bros., La...|[United States of...|  1995-12-22|        0|  101.0|           [English]|Released|Still Yelling. St...|    Grumpier Old Men|false|         6.5|        92|Grumpy Old Men Co...|       2|                     2|                     1|                 1|
# |false|16000000|[Comedy, Drama, R...|31357|               en|Cheated on, mistr...|  3.859495|[Twentieth Centur...|[United States of...|  1995-12-22| 81452156|  127.0|           [English]|Released|Friends are the p...|   Waiting to Exhale|false|         6.1|        34|                NULL|       3|                     1|                     1|                 1|
# |false|       0|            [Comedy]|11862|               en|Just when George ...|  8.387519|[Sandollar Produc...|[United States of...|  1995-02-10| 76578911|  106.0|           [English]|Released|Just When His Wor...|Father of the Bri...|false|         5.7|       173|Father of the Bri...|       1|                     2|                     1|                 1|
# |false|60000000|[Action, Crime, D...|  949|               en|Obsessive master ...| 17.924927|[Regency Enterpri...|[United States of...|  1995-12-15|187436818|  170.0|  [English, Español]|Released|A Los Angeles Cri...|                Heat|false|         7.7|      1886|                NULL|       4|                     3|                     1|                 2|
# |false|58000000|   [Comedy, Romance]|11860|               en|An ugly duckling ...|  6.677277|[Paramount Pictur...|[Germany, United ...|  1995-12-15|        0|  127.0| [Français, English]|Released|You are cordially...|             Sabrina|false|         6.2|       141|                NULL|       2|                     7|                     2|                 2|
# |false|       0|[Action, Adventur...|45325|               en|A mischievous you...|  2.561161|[Walt Disney Pict...|[United States of...|  1995-12-22|        0|   97.0|  [English, Deutsch]|Released|The Original Bad ...|        Tom and Huck|false|         5.4|        45|                NULL|       4|                     1|                     1|                 2|
# |false|35000000|[Action, Adventur...| 9091|               en|International act...|   5.23158|[Universal Pictur...|[United States of...|  1995-12-22| 64350171|  106.0|           [English]|Released|Terror goes into ...|        Sudden Death|false|         5.5|       174|                NULL|       3|                     3|                     1|                 1|
# |false|58000000|[Adventure, Actio...|  710|               en|James Bond must u...| 14.686036|[United Artists, ...|[United Kingdom, ...|  1995-11-16|352194034|  130.0|[English, Pусский...|Released|No limits. No fea...|           GoldenEye|false|         6.6|      1194|James Bond Collec...|       3|                     2|                     2|                 3|
# |false|62000000|[Comedy, Drama, R...| 9087|               en|Widowed U.S. pres...|  6.318445|[Columbia Picture...|[United States of...|  1995-11-17|107879496|  106.0|           [English]|Released|Why can't the mos...|The American Pres...|false|         6.5|       199|                NULL|       3|                     2|                     1|                 1|
# |false|       0|    [Comedy, Horror]|12110|               en|When a lawyer sho...|  5.430331|[Columbia Picture...|[France, United S...|  1995-12-22|        0|   88.0|  [English, Deutsch]|Released|                NULL|Dracula: Dead and...|false|         5.7|       210|                NULL|       2|                     3|                     2|                 2|
# |false|       0|[Family, Animatio...|21032|               en|An outcast half-w...| 12.140733|[Universal Pictur...|[United States of...|  1995-12-22| 11348324|   78.0|           [English]|Released|Part Dog. Part Wo...|               Balto|false|         7.1|       423|    Balto Collection|       3|                     3|                     1|                 1|
# |false|44000000|    [History, Drama]|10858|               en|An all-star cast ...|     5.092|[Hollywood Pictur...|[United States of...|  1995-12-22| 13681765|  192.0|           [English]|Released|Triumphant in Vic...|               Nixon|false|         7.1|        72|                NULL|       2|                     2|                     1|                 1|
# |false|98000000| [Action, Adventure]| 1408|               en|Morgan Adams and ...|  7.284477|[Le Studio Canal+...|[France, Germany,...|  1995-12-22| 10017322|  119.0|    [English, Latin]|Released|The Course Has Be...|    Cutthroat Island|false|         5.7|       137|                NULL|       2|                     4|                     4|                 2|
# |false|52000000|      [Drama, Crime]|  524|               en|The life of the g...| 10.137389|[Universal Pictur...|[France, United S...|  1995-11-22|116112375|  178.0|           [English]|Released|No one stays at t...|              Casino|false|         7.8|      1343|                NULL|       2|                     4|                     2|                 1|
# |false|16500000|    [Drama, Romance]| 4584|               en|Rich Mr. Dashwood...| 10.673167|[Columbia Picture...|[United Kingdom, ...|  1995-12-13|135000000|  136.0|           [English]|Released|Lose your heart a...|Sense and Sensibi...|false|         7.2|       364|                NULL|       2|                     2|                     2|                 1|
# |false| 4000000|     [Crime, Comedy]|    5|               en|It's Ted the Bell...|  9.026586|[Miramax Films, A...|[United States of...|  1995-12-09|  4300000|   98.0|           [English]|Released|Twelve outrageous...|          Four Rooms|false|         6.5|       539|                NULL|       2|                     2|                     1|                 1|
# |false|30000000|[Crime, Comedy, A...| 9273|               en|Summoned from an ...|  8.205448|[O Entertainment,...|[United States of...|  1995-11-10|212385533|   90.0|           [English]|Released|New animals. New ...|Ace Ventura: When...|false|         6.1|      1128|Ace Ventura Colle...|       3|                     3|                     1|                 1|
# |false|60000000|[Action, Comedy, ...|11517|               en|A vengeful New Yo...|  7.337906| [Columbia Pictures]|[United States of...|  1995-11-21| 35431113|  103.0|           [English]|Released|Get on, or GET OU...|         Money Train|false|         5.4|       224|                NULL|       3|                     1|                     1|                 1|
# +-----+--------+--------------------+-----+-----------------+--------------------+----------+--------------------+--------------------+------------+---------+-------+--------------------+--------+--------------------+--------------------+-----+------------+----------+--------------------+--------+----------------------+----------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# Additionally, `status` and `original_language` may be treated as bool, depending on their uniques values:

# %%
df.\
    select(['status']).distinct().\
    show()

df.\
    select(['original_language']).distinct().\
    show()
# Out:
# +---------------+
# |         status|
# +---------------+
# |        Rumored|
# |       Released|
# |Post Production|
# |  In Production|
# |        Planned|
# |       Canceled|
# |           NULL|
# +---------------+
#
# +-----------------+
# |original_language|
# +-----------------+
# |               en|
# |               vi|
# |               nb|
# |               ro|
# |               pl|
# |               cn|
# |               sk|
# |               pt|
# |               sh|
# |               ko|
# |               cs|
# |               sr|
# |               de|
# |               es|
# |               el|
# |               it|
# |               ar|
# |               sv|
# |               nl|
# |               bo|
# +-----------------+
# only showing top 20 rows

# %% [markdown]
# It is not the case. Finally, we save the cleaned data in parquet format:

# %%
df.write.parquet('data/cleaned/movies_metadata', mode='overwrite')

# %% [markdown]
# ## Links

# %%
df = load_and_show('data/links.csv')
# Out:
# root
#  |-- movieId: integer (nullable = true)
#  |-- imdbId: integer (nullable = true)
#  |-- tmdbId: integer (nullable = true)
#
# Number of partitions = 1
# Number of entries/rows = 458430
#
# +-------+------+------+
# |movieId|imdbId|tmdbId|
# +-------+------+------+
# |      1|114709|   862|
# |      2|113497|  8844|
# |      3|113228| 15602|
# |      4|114885| 31357|
# |      5|113041| 11862|
# +-------+------+------+
# only showing top 5 rows

# %% [markdown]
# For now, this doesn't seem to be useful. Let's leave it be.

# %% [markdown]
# ## Keywords

# %%
df = load_and_show('data/keywords.csv')
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- keywords: string (nullable = true)
#
# Number of partitions = 2
# Number of entries/rows = 464190
#
# +-----+--------------------+
# |   id|            keywords|
# +-----+--------------------+
# |  862|[{'id': 931, 'nam...|
# | 8844|[{'id': 10090, 'n...|
# |15602|[{'id': 1495, 'na...|
# |31357|[{'id': 818, 'nam...|
# |11862|[{'id': 1009, 'na...|
# +-----+--------------------+
# only showing top 5 rows

# %% [markdown]
# It is being read correctly and the keywords have the potential to be used as vocabulary for NLP techniques. However, if the keywords' ids are to be trusted, it would require a number of words that far exceeds what my resources can manage (at least 30000 words! That would translate into a number_movies $\times$ 30000 matrix for methods like TF-IDF).
#
# Let's take a sample to look for a way to extract the keywords:

# %%
import pandas as pd
pd_df = df.limit(5).toPandas()
pd_df.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
import re
l_json = pd_df.iloc[0,1]
re.findall(
    pattern=r'(?<=\'name\': \')([^\']*)(?=\')',
    string=l_json
)
# Out:
# ['jealousy',
#  'toy',
#  'boy',
#  'friendship',
#  'friends',
#  'rivalry',
#  'boy next door',
#  'new toy',
#  'toy comes to life']

# %% [markdown]
# Now, an option is to save this list of keywords in the dataframe (like the original list of json's), which should be more accesible:

# %%
from pyspark.sql.functions import regexp_extract_all, lit

df = df.withColumn(
    'keywords_list', 
    regexp_extract_all('keywords', 
        lit(r'(?<=\'name\': \')([^\']*)(?=\')').alias('d'))
    ).drop('keywords')
df.show(5)
# Out:
# +-----+--------------------+
# |   id|       keywords_list|
# +-----+--------------------+
# |  862|[jealousy, toy, b...|
# | 8844|[board game, disa...|
# |15602|[fishing, best fr...|
# |31357|[based on novel, ...|
# |11862|[baby, midlife cr...|
# +-----+--------------------+
# only showing top 5 rows

# %% [markdown]
# Write as parquet:

# %%
df.write.parquet('data/cleaned/keywords', mode='overwrite')

# %% [markdown]
# ## Credits

# %%
df = load_and_show('data/credits.csv')
# Out:
# root
#  |-- cast: string (nullable = true)
#  |-- crew: string (nullable = true)
#  |-- id: integer (nullable = true)
#
# Number of partitions = 20
# Number of entries/rows = 454760
#
# +--------------------+--------------------+-----+
# |                cast|                crew|   id|
# +--------------------+--------------------+-----+
# |[{'cast_id': 14, ...|[{'credit_id': '5...|  862|
# |[{'cast_id': 1, '...|[{'credit_id': '5...| 8844|
# |[{'cast_id': 2, '...|[{'credit_id': '5...|15602|
# |[{'cast_id': 1, '...|[{'credit_id': '5...|31357|
# |[{'cast_id': 1, '...|[{'credit_id': '5...|11862|
# +--------------------+--------------------+-----+
# only showing top 5 rows

# %% [markdown]
# The 'crew' column is specially interesting, as the actors and the directors are mentioned. They may be used in a content-based recommender system, specially the director.
#
# Let's analyse a subset to find a way to extract the director of each movie:

# %%
import pandas as pd
pd_df = df.limit(5).toPandas()
pd_df.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
import re
l_json = pd_df.iloc[0,1]
re.findall(
    pattern=r'(?<=Director\', \'name\': \')([^\']*)(?=\')',
    string=l_json
)
# Out:
# ['John Lasseter', 'Ash Brannon', 'William Reeves', 'Rich Quade']

# %% [markdown]
# Now, let's use PySpark to parallelize this operation when applying it to the `crew` column:

# %%
from pyspark.sql.functions import regexp_extract, col

df = df.withColumn(
    'director', 
    regexp_extract(col('crew'), 
        r'(?<=Director\', \'name\': \')([^\']*)(?=\')', 
        1)
    ).\
    drop('cast', 'crew')
df.show(5)
# Out:
# +-----+---------------+
# |   id|       director|
# +-----+---------------+
# |  862|  John Lasseter|
# | 8844|   Joe Johnston|
# |15602|  Howard Deutch|
# |31357|Forest Whitaker|
# |11862|  Charles Shyer|
# +-----+---------------+
# only showing top 5 rows

# %% [markdown]
# Let's save the director for each movie:

# %%
df.write.parquet('data/cleaned/directors', mode='overwrite')

# %% [markdown]
# Close Spark instance:

# %%
spark.stop()

# %% [markdown]
# ## References
#
# + [The Movies DataSet](https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset?select=ratings.csv)
#
# + [Advances PySpark for EDA](https://www.kaggle.com/code/tientd95/advanced-pyspark-for-exploratory-data-analysis#1.-Initialize-pyspark-framework-and-load-data-into-pyspark's-dataframe-)
#
# + [Spark Sessions](https://sparkbyexamples.com/spark/sparksession-explained-with-examples/)
#
# + [List from Regular Expression](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/api/pyspark.sql.functions.regexp_extract_all.html)
